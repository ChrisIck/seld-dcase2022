# %%
# Extracts the features, labels, and normalizes the development and evaluation split features.
import sys
sys.path.append('..')
import cls_feature_class
import parameters
import sys
import os
import numpy as np

# %%
# use parameter set defined by user
task_id = '1'
params = parameters.get_params(task_id)

# -------------- Extract features and labels for development set -----------------------------
dev_feat_cls = cls_feature_class.FeatureClass(params, is_eval=True)
# # Extract features and normalize them
#print("Extracting Features...")
#dev_feat_cls.extract_all_feature()
#print("Preprocess Features...")
#dev_feat_cls.preprocess_features()
# # Extract labels
print("Extracting Labels...")
dev_feat_cls.extract_all_labels()
# Out:
# SET: 1
# USING DEFAULT PARAMETERS
#
# Loading data from /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_real/target_noiseless
# 	quick_test: False
# 	finetune_mode: False
# 	pretrained_model_weights: models/1_1_foa_dev_split6_model.h5
# 	dataset_dir: /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_real/target_noiseless
# 	feat_label_dir: /scratch/ci411/DCASE_GEN/seld_features/nigens_tau_real/target_noiseless
# 	model_dir: models/
# 	dcase_output_dir: results/
# 	mode: dev
# 	dataset: mic
# 	fs: 24000
# 	hop_len_s: 0.02
# 	label_hop_len_s: 0.1
# 	max_audio_len_s: 60
# 	nb_mel_bins: 64
# 	use_salsalite: False
# 	fmin_doa_salsalite: 50
# 	fmax_doa_salsalite: 2000
# 	fmax_spectra_salsalite: 9000
# 	multi_accdoa: False
# 	thresh_unify: 15
# 	label_sequence_length: 50
# 	batch_size: 128
# 	dropout_rate: 0.05
# 	nb_cnn2d_filt: 64
# 	f_pool_size: [4, 4, 2]
# 	nb_rnn_layers: 2
# 	rnn_size: 128
# 	self_attn: False
# 	nb_heads: 4
# 	nb_fnn_layers: 1
# 	fnn_size: 128
# 	nb_epochs: 100
# 	lr: 0.001
# 	average: macro
# 	lad_doa_thresh: 20
# 	feature_sequence_length: 250
# 	t_pool_size: [5, 1, 1]
# 	patience: 100
# 	unique_classes: 14
# Extracting Labels...
# Computing frame stats:
# 		aud_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_real/target_noiseless/mic_eval
# 		desc_dir None
# 		feat_dir None
# Extracting labels:
# 		aud_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_real/target_noiseless/mic_eval
# 		desc_dir None
# 		label_dir None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 14>()
#       7 # # Extract features and normalize them
#       8 #print("Extracting Features...")
#       9 #dev_feat_cls.extract_all_feature()
#      10 #print("Preprocess Features...")
#      11 #dev_feat_cls.preprocess_features()
#      12 # # Extract labels
#      13 print("Extracting Labels...")
# ---> 14 dev_feat_cls.extract_all_labels()
#
# File ~/seld-dcase2022/cls_feature_class.py:439, in FeatureClass.extract_all_labels(self)
#     436 print('Extracting labels:')
#     437 print('\t\taud_dir {}\n\t\tdesc_dir {}\n\t\tlabel_dir {}'.format(
#     438     self._aud_dir, self._desc_dir, self._label_dir))
# --> 439 create_folder(self._label_dir)
#     440 #for sub_folder in os.listdir(self._desc_dir):
#     441     #loc_desc_folder = os.path.join(self._desc_dir)#, sub_folder)
#     442 for file_cnt, file_name in enumerate(os.listdir(self._desc_dir)):
#
# File ~/seld-dcase2022/cls_feature_class.py:645, in create_folder(folder_name)
#     644 def create_folder(folder_name):
# --> 645     if not os.path.exists(folder_name):
#     646         print('{} folder does not exist, creating it.'.format(folder_name))
#     647         os.makedirs(folder_name)
#
# File /scratch/ci411/.conda/envs/s3d_env/lib/python3.8/genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not NoneType

# %%
# use parameter set defined by user
task_id = '1s'
params = parameters.get_params(task_id)

# -------------- Extract features and labels for development set -----------------------------
dev_feat_cls = cls_feature_class.FeatureClass(params)
# # Extract features and normalize them
#print("Extracting Features...")
#dev_feat_cls.extract_all_feature()
#print("Preprocess Features...")
#dev_feat_cls.preprocess_features()
# # Extract labels
print("Extracting Labels...")
dev_feat_cls.extract_all_labels()
# Out:
# SET: 1s
# USING DEFAULT PARAMETERS
#
# Loading data from /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless
# 	quick_test: False
# 	finetune_mode: False
# 	pretrained_model_weights: models/1_1_foa_dev_split6_model.h5
# 	dataset_dir: /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless
# 	feat_label_dir: /scratch/ci411/DCASE_GEN/seld_features/nigens_tau_sim/target_noiseless
# 	model_dir: models/
# 	dcase_output_dir: results/
# 	mode: dev
# 	dataset: mic
# 	fs: 24000
# 	hop_len_s: 0.02
# 	label_hop_len_s: 0.1
# 	max_audio_len_s: 60
# 	nb_mel_bins: 64
# 	use_salsalite: False
# 	fmin_doa_salsalite: 50
# 	fmax_doa_salsalite: 2000
# 	fmax_spectra_salsalite: 9000
# 	multi_accdoa: False
# 	thresh_unify: 15
# 	label_sequence_length: 50
# 	batch_size: 128
# 	dropout_rate: 0.05
# 	nb_cnn2d_filt: 64
# 	f_pool_size: [4, 4, 2]
# 	nb_rnn_layers: 2
# 	rnn_size: 128
# 	self_attn: False
# 	nb_heads: 4
# 	nb_fnn_layers: 1
# 	fnn_size: 128
# 	nb_epochs: 100
# 	lr: 0.001
# 	average: macro
# 	lad_doa_thresh: 20
# 	feature_sequence_length: 250
# 	t_pool_size: [5, 1, 1]
# 	patience: 100
# 	unique_classes: 14
# Extracting Labels...
# Computing frame stats:
# 		aud_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless/mic_dev
# 		desc_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless/metadata_dev
# 		feat_dir None
# Extracting labels:
# 		aud_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless/mic_dev
# 		desc_dir /scratch/ci411/DCASE_GEN/mixtures/nigens_tau_sim/target_noiseless/metadata_dev
# 		label_dir /scratch/ci411/DCASE_GEN/seld_features/nigens_tau_sim/target_noiseless/mic_dev_label
# 0: fold1_room1_mix071.csv, (600, 56)
# 1: fold1_room3_mix062.csv, (600, 56)
# 2: fold1_room3_mix058.csv, (600, 56)
# 3: fold1_room2_mix020.csv, (600, 56)
# 4: fold1_room1_mix049.csv, (600, 56)
# 5: fold1_room5_mix146.csv, (600, 56)
# 6: fold1_room1_mix097.csv, (600, 56)
# 7: fold1_room6_mix007.csv, (600, 56)
# 8: fold1_room3_mix055.csv, (600, 56)
# 9: fold1_room1_mix095.csv, (600, 56)
# 10: fold1_room3_mix012.csv, (600, 56)
# 11: fold1_room2_mix017.csv, (600, 56)
# 12: fold1_room6_mix120.csv, (600, 56)
# 13: fold1_room6_mix037.csv, (600, 56)
# 14: fold1_room3_mix019.csv, (600, 56)
# 15: fold1_room3_mix053.csv, (600, 56)
# 16: fold1_room4_mix021.csv, (600, 56)
# 17: fold1_room3_mix139.csv, (600, 56)
# 18: fold1_room2_mix108.csv, (600, 56)
# 19: fold1_room5_mix031.csv, (600, 56)
# 20: fold1_room5_mix134.csv, (600, 56)
# 21: fold1_room1_mix088.csv, (600, 56)
# 22: fold1_room6_mix083.csv, (600, 56)
# 23: fold1_room6_mix112.csv, (600, 56)
# 24: fold1_room2_mix010.csv, (600, 56)
# 25: fold1_room6_mix051.csv, (600, 56)
# 26: fold1_room2_mix041.csv, (600, 56)
# 27: fold1_room1_mix078.csv, (600, 56)
# 28: fold1_room5_mix102.csv, (600, 56)
# 29: fold1_room1_mix025.csv, (600, 56)
# 30: fold1_room6_mix023.csv, (600, 56)
# 31: fold1_room4_mix050.csv, (600, 56)
# 32: fold1_room5_mix128.csv, (600, 56)
# 33: fold1_room1_mix113.csv, (600, 56)
# 34: fold1_room5_mix003.csv, (600, 56)
# 35: fold1_room3_mix069.csv, (600, 56)
# 36: fold1_room5_mix080.csv, (600, 56)
# 37: fold1_room6_mix076.csv, (600, 56)
# 38: fold1_room5_mix097.csv, (600, 56)
# 39: fold1_room6_mix135.csv, (600, 56)
# 40: fold1_room1_mix030.csv, (600, 56)
# 41: fold1_room3_mix042.csv, (600, 56)
# 42: fold1_room4_mix142.csv, (600, 56)
# 43: fold1_room5_mix142.csv, (600, 56)
# 44: fold1_room2_mix095.csv, (600, 56)
# 45: fold1_room1_mix136.csv, (600, 56)
# 46: fold1_room1_mix082.csv, (600, 56)
# 47: fold1_room6_mix058.csv, (600, 56)
# 48: fold1_room1_mix047.csv, (600, 56)
# 49: fold1_room3_mix037.csv, (600, 56)
# 50: fold1_room3_mix077.csv, (600, 56)
# 51: fold1_room5_mix028.csv, (600, 56)
# 52: fold1_room6_mix041.csv, (600, 56)
# 53: fold1_room5_mix103.csv, (600, 56)
# 54: fold1_room3_mix031.csv, (600, 56)
# 55: fold1_room4_mix047.csv, (600, 56)
# 56: fold1_room3_mix096.csv, (600, 56)
# 57: fold1_room2_mix025.csv, (600, 56)
# 58: fold1_room4_mix147.csv, (600, 56)
# 59: fold1_room4_mix062.csv, (600, 56)
# 60: fold1_room3_mix112.csv, (600, 56)
# 61: fold1_room6_mix032.csv, (600, 56)
# 62: fold1_room1_mix141.csv, (600, 56)
# 63: fold1_room4_mix136.csv, (600, 56)
# 64: fold1_room4_mix098.csv, (600, 56)
# 65: fold1_room4_mix043.csv, (600, 56)
# 66: fold1_room4_mix063.csv, (600, 56)
# 67: fold1_room3_mix076.csv, (600, 56)
# 68: fold1_room5_mix095.csv, (600, 56)
# 69: fold1_room4_mix129.csv, (600, 56)
# 70: fold1_room2_mix104.csv, (600, 56)
# 71: fold1_room1_mix005.csv, (600, 56)
# 72: fold1_room4_mix008.csv, (600, 56)
# 73: fold1_room2_mix085.csv, (600, 56)
# 74: fold1_room1_mix051.csv, (600, 56)
# 75: fold1_room6_mix010.csv, (600, 56)
# 76: fold1_room3_mix063.csv, (600, 56)
# 77: fold1_room1_mix060.csv, (600, 56)
# 78: fold1_room5_mix077.csv, (600, 56)
# 79: fold1_room1_mix085.csv, (600, 56)
# 80: fold1_room5_mix075.csv, (600, 56)
# 81: fold1_room6_mix030.csv, (600, 56)
# 82: fold1_room4_mix148.csv, (600, 56)
# 83: fold1_room4_mix145.csv, (600, 56)
# 84: fold1_room2_mix055.csv, (600, 56)
# 85: fold1_room6_mix082.csv, (600, 56)
# 86: fold1_room1_mix087.csv, (600, 56)
# 87: fold1_room1_mix039.csv, (600, 56)
# 88: fold1_room6_mix093.csv, (600, 56)
# 89: fold1_room5_mix088.csv, (600, 56)
# 90: fold1_room5_mix006.csv, (600, 56)
# 91: fold1_room5_mix131.csv, (600, 56)
# 92: fold1_room3_mix075.csv, (600, 56)
# 93: fold1_room5_mix012.csv, (600, 56)
# 94: fold1_room2_mix065.csv, (600, 56)
# 95: fold1_room6_mix050.csv, (600, 56)
# 96: fold1_room1_mix004.csv, (600, 56)
# 97: fold1_room6_mix004.csv, (600, 56)
# 98: fold1_room3_mix144.csv, (600, 56)
# 99: fold1_room2_mix094.csv, (600, 56)
# 100: fold1_room1_mix048.csv, (600, 56)
# 101: fold1_room3_mix052.csv, (600, 56)
# 102: fold1_room2_mix071.csv, (600, 56)
# 103: fold1_room4_mix054.csv, (600, 56)
# 104: fold1_room2_mix007.csv, (600, 56)
# 105: fold1_room4_mix087.csv, (600, 56)
# 106: fold1_room4_mix010.csv, (600, 56)
# 107: fold1_room6_mix011.csv, (600, 56)
# 108: fold1_room3_mix040.csv, (600, 56)
# 109: fold1_room6_mix102.csv, (600, 56)
# 110: fold1_room5_mix083.csv, (600, 56)
# 111: fold1_room6_mix081.csv, (600, 56)
# 112: fold1_room3_mix142.csv, (600, 56)
# 113: fold1_room1_mix053.csv, (600, 56)
# 114: fold1_room1_mix098.csv, (600, 56)
# 115: fold1_room1_mix072.csv, (600, 56)
# 116: fold1_room2_mix077.csv, (600, 56)
# 117: fold1_room1_mix129.csv, (600, 56)
# 118: fold1_room1_mix070.csv, (600, 56)
# 119: fold1_room4_mix117.csv, (600, 56)
# 120: fold1_room5_mix136.csv, (600, 56)
# 121: fold1_room1_mix043.csv, (600, 56)
# 122: fold1_room3_mix149.csv, (600, 56)
# 123: fold1_room6_mix039.csv, (600, 56)
# 124: fold1_room6_mix085.csv, (600, 56)
# 125: fold1_room6_mix020.csv, (600, 56)
# 126: fold1_room5_mix037.csv, (600, 56)
# 127: fold1_room3_mix025.csv, (600, 56)
# 128: fold1_room1_mix081.csv, (600, 56)
# 129: fold1_room1_mix111.csv, (600, 56)
# 130: fold1_room2_mix012.csv, (600, 56)
# 131: fold1_room5_mix109.csv, (600, 56)
# 132: fold1_room6_mix074.csv, (600, 56)
# 133: fold1_room4_mix113.csv, (600, 56)
# 134: fold1_room3_mix087.csv, (600, 56)
# 135: fold1_room5_mix150.csv, (600, 56)
# 136: fold1_room4_mix114.csv, (600, 56)
# 137: fold1_room4_mix066.csv, (600, 56)
# 138: fold1_room4_mix048.csv, (600, 56)
# 139: fold1_room6_mix016.csv, (600, 56)
# 140: fold1_room5_mix091.csv, (600, 56)
# 141: fold1_room1_mix015.csv, (600, 56)
# 142: fold1_room6_mix062.csv, (600, 56)
# 143: fold1_room5_mix071.csv, (600, 56)
# 144: fold1_room6_mix115.csv, (600, 56)
# 145: fold1_room6_mix106.csv, (600, 56)
# 146: fold1_room6_mix022.csv, (600, 56)
# 147: fold1_room6_mix139.csv, (600, 56)
# 148: fold1_room3_mix134.csv, (600, 56)
# 149: fold1_room2_mix080.csv, (600, 56)
# 150: fold1_room6_mix097.csv, (600, 56)
# 151: fold1_room3_mix057.csv, (600, 56)
# 152: fold1_room1_mix067.csv, (600, 56)
# 153: fold1_room3_mix001.csv, (600, 56)
# 154: fold1_room4_mix138.csv, (600, 56)
# 155: fold1_room3_mix018.csv, (600, 56)
# 156: fold1_room5_mix034.csv, (600, 56)
# 157: fold1_room1_mix135.csv, (600, 56)
# 158: fold1_room6_mix078.csv, (600, 56)
# 159: fold1_room2_mix061.csv, (600, 56)
# 160: fold1_room2_mix023.csv, (600, 56)
# 161: fold1_room5_mix149.csv, (600, 56)
# 162: fold1_room6_mix090.csv, (600, 56)
# 163: fold1_room3_mix006.csv, (600, 56)
# 164: fold1_room5_mix017.csv, (600, 56)
# 165: fold1_room3_mix060.csv, (600, 56)
# 166: fold1_room4_mix072.csv, (600, 56)
# 167: fold1_room6_mix043.csv, (600, 56)
# 168: fold1_room4_mix040.csv, (600, 56)
# 169: fold1_room1_mix133.csv, (600, 56)
# 170: fold1_room2_mix078.csv, (600, 56)
# 171: fold1_room3_mix127.csv, (600, 56)
# 172: fold1_room1_mix079.csv, (600, 56)
# 173: fold1_room4_mix015.csv, (600, 56)
# 174: fold1_room5_mix062.csv, (600, 56)
# 175: fold1_room3_mix015.csv, (600, 56)
# 176: fold1_room6_mix094.csv, (600, 56)
# 177: fold1_room2_mix144.csv, (600, 56)
# 178: fold1_room4_mix076.csv, (600, 56)
# 179: fold1_room3_mix129.csv, (600, 56)
# 180: fold1_room4_mix078.csv, (600, 56)
# 181: fold1_room1_mix077.csv, (600, 56)
# 182: fold1_room1_mix119.csv, (600, 56)
# 183: fold1_room2_mix141.csv, (600, 56)
# 184: fold1_room4_mix116.csv, (600, 56)
# 185: fold1_room4_mix134.csv, (600, 56)
# 186: fold1_room3_mix098.csv, (600, 56)
# 187: fold1_room4_mix100.csv, (600, 56)
# 188: fold1_room5_mix132.csv, (600, 56)
# 189: fold1_room4_mix119.csv, (600, 56)
# 190: fold1_room5_mix135.csv, (600, 56)
# 191: fold1_room3_mix119.csv, (600, 56)
# 192: fold1_room2_mix118.csv, (600, 56)
# 193: fold1_room3_mix111.csv, (600, 56)
# 194: fold1_room5_mix022.csv, (600, 56)
# 195: fold1_room5_mix033.csv, (600, 56)
# 196: fold1_room4_mix065.csv, (600, 56)
# 197: fold1_room1_mix140.csv, (600, 56)
# 198: fold1_room4_mix022.csv, (600, 56)
# 199: fold1_room3_mix128.csv, (600, 56)
# 200: fold1_room1_mix112.csv, (600, 56)
# 201: fold1_room5_mix108.csv, (600, 56)
# 202: fold1_room5_mix061.csv, (600, 56)
# 203: fold1_room5_mix094.csv, (600, 56)
# 204: fold1_room5_mix005.csv, (600, 56)
# 205: fold1_room1_mix028.csv, (600, 56)
# 206: fold1_room1_mix057.csv, (600, 56)
# 207: fold1_room1_mix093.csv, (600, 56)
# 208: fold1_room5_mix008.csv, (600, 56)
# 209: fold1_room6_mix148.csv, (600, 56)
# 210: fold1_room1_mix062.csv, (600, 56)
# 211: fold1_room5_mix072.csv, (600, 56)
# 212: fold1_room4_mix080.csv, (600, 56)
# 213: fold1_room1_mix105.csv, (600, 56)
# 214: fold1_room1_mix117.csv, (600, 56)
# 215: fold1_room3_mix088.csv, (600, 56)
# 216: fold1_room4_mix041.csv, (600, 56)
# 217: fold1_room5_mix050.csv, (600, 56)
# 218: fold1_room2_mix081.csv, (600, 56)
# 219: fold1_room6_mix013.csv, (600, 56)
# 220: fold1_room2_mix003.csv, (600, 56)
# 221: fold1_room4_mix036.csv, (600, 56)
# 222: fold1_room5_mix137.csv, (600, 56)
# 223: fold1_room6_mix034.csv, (600, 56)
# 224: fold1_room2_mix109.csv, (600, 56)
# 225: fold1_room2_mix089.csv, (600, 56)
# 226: fold1_room5_mix057.csv, (600, 56)
# 227: fold1_room5_mix107.csv, (600, 56)
# 228: fold1_room4_mix055.csv, (600, 56)
# 229: fold1_room3_mix094.csv, (600, 56)
# 230: fold1_room5_mix002.csv, (600, 56)
# 231: fold1_room4_mix131.csv, (600, 56)
# 232: fold1_room2_mix039.csv, (600, 56)
# 233: fold1_room4_mix049.csv, (600, 56)
# 234: fold1_room6_mix066.csv, (600, 56)
# 235: fold1_room4_mix107.csv, (600, 56)
# 236: fold1_room3_mix116.csv, (600, 56)
# 237: fold1_room2_mix124.csv, (600, 56)
# 238: fold1_room1_mix041.csv, (600, 56)
# 239: fold1_room2_mix043.csv, (600, 56)
# 240: fold1_room6_mix024.csv, (600, 56)
# 241: fold1_room3_mix017.csv, (600, 56)
# 242: fold1_room4_mix110.csv, (600, 56)
# 243: fold1_room5_mix059.csv, (600, 56)
# 244: fold1_room1_mix027.csv, (600, 56)
# 245: fold1_room2_mix100.csv, (600, 56)
# 246: fold1_room6_mix103.csv, (600, 56)
# 247: fold1_room3_mix071.csv, (600, 56)
# 248: fold1_room1_mix115.csv, (600, 56)
# 249: fold1_room1_mix065.csv, (600, 56)
# 250: fold1_room1_mix026.csv, (600, 56)
# 251: fold1_room2_mix111.csv, (600, 56)
# 252: fold1_room1_mix042.csv, (600, 56)
# 253: fold1_room4_mix092.csv, (600, 56)
# 254: fold1_room5_mix144.csv, (600, 56)
# 255: fold1_room5_mix116.csv, (600, 56)
# 256: fold1_room2_mix101.csv, (600, 56)
# 257: fold1_room1_mix099.csv, (600, 56)
# 258: fold1_room3_mix093.csv, (600, 56)
# 259: fold1_room6_mix065.csv, (600, 56)
# 260: fold1_room6_mix125.csv, (600, 56)
# 261: fold1_room6_mix049.csv, (600, 56)
# 262: fold1_room3_mix047.csv, (600, 56)
# 263: fold1_room5_mix035.csv, (600, 56)
# 264: fold1_room1_mix138.csv, (600, 56)
# 265: fold1_room3_mix051.csv, (600, 56)
# 266: fold1_room2_mix045.csv, (600, 56)
# 267: fold1_room1_mix107.csv, (600, 56)
# 268: fold1_room6_mix134.csv, (600, 56)
# 269: fold1_room6_mix100.csv, (600, 56)
# 270: fold1_room5_mix018.csv, (600, 56)
# 271: fold1_room5_mix009.csv, (600, 56)
# 272: fold1_room2_mix009.csv, (600, 56)
# 273: fold1_room2_mix105.csv, (600, 56)
# 274: fold1_room1_mix080.csv, (600, 56)
# 275: fold1_room1_mix023.csv, (600, 56)
# 276: fold1_room3_mix044.csv, (600, 56)
# 277: fold1_room5_mix127.csv, (600, 56)
# 278: fold1_room5_mix112.csv, (600, 56)
# 279: fold1_room3_mix104.csv, (600, 56)
# 280: fold1_room3_mix080.csv, (600, 56)
# 281: fold1_room6_mix021.csv, (600, 56)
# 282: fold1_room1_mix014.csv, (600, 56)
# 283: fold1_room4_mix091.csv, (600, 56)
# 284: fold1_room4_mix120.csv, (600, 56)
# 285: fold1_room2_mix086.csv, (600, 56)
# 286: fold1_room5_mix139.csv, (600, 56)
# 287: fold1_room5_mix104.csv, (600, 56)
# 288: fold1_room6_mix027.csv, (600, 56)
# 289: fold1_room5_mix073.csv, (600, 56)
# 290: fold1_room1_mix127.csv, (600, 56)
# 291: fold1_room4_mix121.csv, (600, 56)
# 292: fold1_room6_mix002.csv, (600, 56)
# 293: fold1_room5_mix070.csv, (600, 56)
# 294: fold1_room5_mix004.csv, (600, 56)
# 295: fold1_room3_mix045.csv, (600, 56)
# 296: fold1_room2_mix117.csv, (600, 56)
# 297: fold1_room1_mix009.csv, (600, 56)
# 298: fold1_room1_mix055.csv, (600, 56)
# 299: fold1_room5_mix120.csv, (600, 56)
# 300: fold1_room5_mix001.csv, (600, 56)
# 301: fold1_room5_mix078.csv, (600, 56)
# 302: fold1_room6_mix146.csv, (600, 56)
# 303: fold1_room6_mix067.csv, (600, 56)
# 304: fold1_room4_mix004.csv, (600, 56)
# 305: fold1_room1_mix084.csv, (600, 56)
# 306: fold1_room6_mix143.csv, (600, 56)
# 307: fold1_room6_mix126.csv, (600, 56)
# 308: fold1_room4_mix140.csv, (600, 56)
# 309: fold1_room1_mix019.csv, (600, 56)
# 310: fold1_room5_mix036.csv, (600, 56)
# 311: fold1_room4_mix105.csv, (600, 56)
# 312: fold1_room5_mix098.csv, (600, 56)
# 313: fold1_room2_mix022.csv, (600, 56)
# 314: fold1_room1_mix013.csv, (600, 56)
# 315: fold1_room3_mix021.csv, (600, 56)
# 316: fold1_room4_mix103.csv, (600, 56)
# 317: fold1_room5_mix140.csv, (600, 56)
# 318: fold1_room5_mix038.csv, (600, 56)
# 319: fold1_room5_mix042.csv, (600, 56)
# 320: fold1_room1_mix101.csv, (600, 56)
# 321: fold1_room6_mix068.csv, (600, 56)
# 322: fold1_room4_mix079.csv, (600, 56)
# 323: fold1_room4_mix106.csv, (600, 56)
# 324: fold1_room4_mix024.csv, (600, 56)
# 325: fold1_room1_mix050.csv, (600, 56)
# 326: fold1_room6_mix018.csv, (600, 56)
# 327: fold1_room1_mix146.csv, (600, 56)
# 328: fold1_room4_mix074.csv, (600, 56)
# 329: fold1_room2_mix075.csv, (600, 56)
# 330: fold1_room3_mix078.csv, (600, 56)
# 331: fold1_room4_mix081.csv, (600, 56)
# 332: fold1_room3_mix089.csv, (600, 56)
# 333: fold1_room3_mix030.csv, (600, 56)
# 334: fold1_room5_mix027.csv, (600, 56)
# 335: fold1_room5_mix115.csv, (600, 56)
# 336: fold1_room4_mix009.csv, (600, 56)
# 337: fold1_room4_mix139.csv, (600, 56)
# 338: fold1_room6_mix132.csv, (600, 56)
# 339: fold1_room1_mix010.csv, (600, 56)
# 340: fold1_room5_mix124.csv, (600, 56)
# 341: fold1_room3_mix146.csv, (600, 56)
# 342: fold1_room6_mix107.csv, (600, 56)
# 343: fold1_room5_mix047.csv, (600, 56)
# 344: fold1_room1_mix118.csv, (600, 56)
# 345: fold1_room2_mix112.csv, (600, 56)
# 346: fold1_room1_mix068.csv, (600, 56)
# 347: fold1_room2_mix113.csv, (600, 56)
# 348: fold1_room3_mix035.csv, (600, 56)
# 349: fold1_room3_mix110.csv, (600, 56)
# 350: fold1_room1_mix069.csv, (600, 56)
# 351: fold1_room2_mix064.csv, (600, 56)
# 352: fold1_room1_mix007.csv, (600, 56)
# 353: fold1_room3_mix032.csv, (600, 56)
# 354: fold1_room3_mix138.csv, (600, 56)
# 355: fold1_room4_mix029.csv, (600, 56)
# 356: fold1_room1_mix020.csv, (600, 56)
# 357: fold1_room4_mix035.csv, (600, 56)
# 358: fold1_room1_mix149.csv, (600, 56)
# 359: fold1_room5_mix041.csv, (600, 56)
# 360: fold1_room3_mix067.csv, (600, 56)
# 361: fold1_room2_mix056.csv, (600, 56)
# 362: fold1_room2_mix029.csv, (600, 56)
# 363: fold1_room1_mix035.csv, (600, 56)
# 364: fold1_room4_mix068.csv, (600, 56)
# 365: fold1_room2_mix136.csv, (600, 56)
# 366: fold1_room3_mix092.csv, (600, 56)
# 367: fold1_room1_mix132.csv, (600, 56)
# 368: fold1_room1_mix059.csv, (600, 56)
# 369: fold1_room6_mix127.csv, (600, 56)
# 370: fold1_room2_mix126.csv, (600, 56)
# 371: fold1_room2_mix096.csv, (600, 56)
# 372: fold1_room4_mix089.csv, (600, 56)
# 373: fold1_room2_mix033.csv, (600, 56)
# 374: fold1_room2_mix102.csv, (600, 56)
# 375: fold1_room3_mix122.csv, (600, 56)
# 376: fold1_room2_mix116.csv, (600, 56)
# 377: fold1_room2_mix027.csv, (600, 56)
# 378: fold1_room4_mix039.csv, (600, 56)
# 379: fold1_room5_mix032.csv, (600, 56)
# 380: fold1_room6_mix077.csv, (600, 56)
# 381: fold1_room5_mix063.csv, (600, 56)
# 382: fold1_room3_mix135.csv, (600, 56)
# 383: fold1_room2_mix030.csv, (600, 56)
# 384: fold1_room4_mix025.csv, (600, 56)
# 385: fold1_room5_mix090.csv, (600, 56)
# 386: fold1_room4_mix023.csv, (600, 56)
# 387: fold1_room1_mix147.csv, (600, 56)
# 388: fold1_room5_mix043.csv, (600, 56)
# 389: fold1_room6_mix029.csv, (600, 56)
# 390: fold1_room1_mix011.csv, (600, 56)
# 391: fold1_room3_mix029.csv, (600, 56)
# 392: fold1_room2_mix142.csv, (600, 56)
# 393: fold1_room1_mix144.csv, (600, 56)
# 394: fold1_room1_mix110.csv, (600, 56)
# 395: fold1_room4_mix094.csv, (600, 56)
# 396: fold1_room5_mix049.csv, (600, 56)
# 397: fold1_room5_mix010.csv, (600, 56)
# 398: fold1_room2_mix052.csv, (600, 56)
# 399: fold1_room2_mix047.csv, (600, 56)
# 400: fold1_room4_mix125.csv, (600, 56)
# 401: fold1_room6_mix105.csv, (600, 56)
# 402: fold1_room4_mix083.csv, (600, 56)
# 403: fold1_room6_mix026.csv, (600, 56)
# 404: fold1_room2_mix084.csv, (600, 56)
# 405: fold1_room1_mix073.csv, (600, 56)
# 406: fold1_room1_mix109.csv, (600, 56)
# 407: fold1_room2_mix090.csv, (600, 56)
# 408: fold1_room4_mix150.csv, (600, 56)
# 409: fold1_room2_mix060.csv, (600, 56)
# 410: fold1_room2_mix004.csv, (600, 56)
# 411: fold1_room2_mix008.csv, (600, 56)
# 412: fold1_room6_mix131.csv, (600, 56)
# 413: fold1_room2_mix128.csv, (600, 56)
# 414: fold1_room3_mix061.csv, (600, 56)
# 415: fold1_room4_mix034.csv, (600, 56)
# 416: fold1_room5_mix015.csv, (600, 56)
# 417: fold1_room6_mix042.csv, (600, 56)
# 418: fold1_room5_mix067.csv, (600, 56)
# 419: fold1_room1_mix038.csv, (600, 56)
# 420: fold1_room4_mix075.csv, (600, 56)
# 421: fold1_room6_mix070.csv, (600, 56)
# 422: fold1_room2_mix006.csv, (600, 56)
# 423: fold1_room3_mix143.csv, (600, 56)
# 424: fold1_room4_mix102.csv, (600, 56)
# 425: fold1_room3_mix073.csv, (600, 56)
# 426: fold1_room4_mix030.csv, (600, 56)
# 427: fold1_room2_mix119.csv, (600, 56)
# 428: fold1_room1_mix006.csv, (600, 56)
# 429: fold1_room4_mix088.csv, (600, 56)
# 430: fold1_room3_mix072.csv, (600, 56)
# 431: fold1_room3_mix070.csv, (600, 56)
# 432: fold1_room4_mix053.csv, (600, 56)
# 433: fold1_room1_mix018.csv, (600, 56)
# 434: fold1_room5_mix053.csv, (600, 56)
# 435: fold1_room2_mix107.csv, (600, 56)
# 436: fold1_room6_mix005.csv, (600, 56)
# 437: fold1_room6_mix144.csv, (600, 56)
# 438: fold1_room5_mix123.csv, (600, 56)
# 439: fold1_room5_mix082.csv, (600, 56)
# 440: fold1_room2_mix088.csv, (600, 56)
# 441: fold1_room5_mix051.csv, (600, 56)
# 442: fold1_room2_mix087.csv, (600, 56)
# 443: fold1_room5_mix100.csv, (600, 56)
# 444: fold1_room6_mix091.csv, (600, 56)
# 445: fold1_room4_mix002.csv, (600, 56)
# 446: fold1_room2_mix125.csv, (600, 56)
# 447: fold1_room5_mix093.csv, (600, 56)
# 448: fold1_room5_mix048.csv, (600, 56)
# 449: fold1_room3_mix002.csv, (600, 56)
# 450: fold1_room6_mix128.csv, (600, 56)
# 451: fold1_room5_mix044.csv, (600, 56)
# 452: fold1_room2_mix021.csv, (600, 56)
# 453: fold1_room4_mix071.csv, (600, 56)
# 454: fold1_room3_mix145.csv, (600, 56)
# 455: fold1_room3_mix033.csv, (600, 56)
# 456: fold1_room4_mix059.csv, (600, 56)
# 457: fold1_room1_mix102.csv, (600, 56)
# 458: fold1_room4_mix005.csv, (600, 56)
# 459: fold1_room4_mix020.csv, (600, 56)
# 460: fold1_room4_mix028.csv, (600, 56)
# 461: fold1_room4_mix112.csv, (600, 56)
# 462: fold1_room4_mix086.csv, (600, 56)
# 463: fold1_room5_mix011.csv, (600, 56)
# 464: fold1_room3_mix086.csv, (600, 56)
# 465: fold1_room4_mix014.csv, (600, 56)
# 466: fold1_room6_mix069.csv, (600, 56)
# 467: fold1_room4_mix064.csv, (600, 56)
# 468: fold1_room4_mix144.csv, (600, 56)
# 469: fold1_room3_mix024.csv, (600, 56)
# 470: fold1_room1_mix033.csv, (600, 56)
# 471: fold1_room3_mix150.csv, (600, 56)
# 472: fold1_room6_mix040.csv, (600, 56)
# 473: fold1_room2_mix083.csv, (600, 56)
# 474: fold1_room4_mix057.csv, (600, 56)
# 475: fold1_room2_mix066.csv, (600, 56)
# 476: fold1_room1_mix032.csv, (600, 56)
# 477: fold1_room2_mix115.csv, (600, 56)
# 478: fold1_room6_mix140.csv, (600, 56)
# 479: fold1_room3_mix114.csv, (600, 56)
# 480: fold1_room2_mix149.csv, (600, 56)
# 481: fold1_room3_mix103.csv, (600, 56)
# 482: fold1_room4_mix011.csv, (600, 56)
# 483: fold1_room2_mix150.csv, (600, 56)
# 484: fold1_room5_mix143.csv, (600, 56)
# 485: fold1_room2_mix103.csv, (600, 56)
# 486: fold1_room4_mix146.csv, (600, 56)
# 487: fold1_room5_mix052.csv, (600, 56)
# 488: fold1_room6_mix001.csv, (600, 56)
# 489: fold1_room1_mix089.csv, (600, 56)
# 490: fold1_room4_mix051.csv, (600, 56)
# 491: fold1_room1_mix045.csv, (600, 56)
# 492: fold1_room3_mix013.csv, (600, 56)
# 493: fold1_room2_mix137.csv, (600, 56)
# 494: fold1_room6_mix111.csv, (600, 56)
# 495: fold1_room5_mix141.csv, (600, 56)
# 496: fold1_room6_mix063.csv, (600, 56)
# 497: fold1_room4_mix013.csv, (600, 56)
# 498: fold1_room3_mix132.csv, (600, 56)
# 499: fold1_room2_mix068.csv, (600, 56)
# 500: fold1_room5_mix121.csv, (600, 56)
# 501: fold1_room3_mix137.csv, (600, 56)
# 502: fold1_room4_mix019.csv, (600, 56)
# 503: fold1_room6_mix113.csv, (600, 56)
# 504: fold1_room6_mix136.csv, (600, 56)
# 505: fold1_room6_mix141.csv, (600, 56)
# 506: fold1_room5_mix138.csv, (600, 56)
# 507: fold1_room5_mix125.csv, (600, 56)
# 508: fold1_room6_mix046.csv, (600, 56)
# 509: fold1_room4_mix058.csv, (600, 56)
# 510: fold1_room3_mix141.csv, (600, 56)
# 511: fold1_room3_mix004.csv, (600, 56)
# 512: fold1_room3_mix130.csv, (600, 56)
# 513: fold1_room5_mix118.csv, (600, 56)
# 514: fold1_room4_mix073.csv, (600, 56)
# 515: fold1_room1_mix058.csv, (600, 56)
# 516: fold1_room1_mix142.csv, (600, 56)
# 517: fold1_room6_mix110.csv, (600, 56)
# 518: fold1_room1_mix034.csv, (600, 56)
# 519: fold1_room1_mix125.csv, (600, 56)
# 520: fold1_room6_mix036.csv, (600, 56)
# 521: fold1_room1_mix086.csv, (600, 56)
# 522: fold1_room4_mix077.csv, (600, 56)
# 523: fold1_room5_mix105.csv, (600, 56)
# 524: fold1_room5_mix092.csv, (600, 56)
# 525: fold1_room5_mix084.csv, (600, 56)
# 526: fold1_room3_mix041.csv, (600, 56)
# 527: fold1_room2_mix120.csv, (600, 56)
# 528: fold1_room2_mix138.csv, (600, 56)
# 529: fold1_room6_mix028.csv, (600, 56)
# 530: fold1_room6_mix133.csv, (600, 56)
# 531: fold1_room2_mix028.csv, (600, 56)
# 532: fold1_room4_mix108.csv, (600, 56)
# 533: fold1_room2_mix034.csv, (600, 56)
# 534: fold1_room4_mix061.csv, (600, 56)
# 535: fold1_room3_mix027.csv, (600, 56)
# 536: fold1_room4_mix084.csv, (600, 56)
# 537: fold1_room2_mix014.csv, (600, 56)
# 538: fold1_room6_mix086.csv, (600, 56)
# 539: fold1_room1_mix103.csv, (600, 56)
# 540: fold1_room1_mix008.csv, (600, 56)
# 541: fold1_room1_mix076.csv, (600, 56)
# 542: fold1_room6_mix087.csv, (600, 56)
# 543: fold1_room4_mix093.csv, (600, 56)
# 544: fold1_room3_mix046.csv, (600, 56)
# 545: fold1_room3_mix049.csv, (600, 56)
# 546: fold1_room1_mix003.csv, (600, 56)
# 547: fold1_room1_mix074.csv, (600, 56)
# 548: fold1_room5_mix023.csv, (600, 56)
# 549: fold1_room2_mix018.csv, (600, 56)
# 550: fold1_room2_mix132.csv, (600, 56)
# 551: fold1_room6_mix072.csv, (600, 56)
# 552: fold1_room3_mix131.csv, (600, 56)
# 553: fold1_room5_mix110.csv, (600, 56)
# 554: fold1_room1_mix046.csv, (600, 56)
# 555: fold1_room6_mix084.csv, (600, 56)
# 556: fold1_room4_mix012.csv, (600, 56)
# 557: fold1_room1_mix106.csv, (600, 56)
# 558: fold1_room4_mix090.csv, (600, 56)
# 559: fold1_room5_mix085.csv, (600, 56)
# 560: fold1_room3_mix014.csv, (600, 56)
# 561: fold1_room2_mix110.csv, (600, 56)
# 562: fold1_room4_mix123.csv, (600, 56)
# 563: fold1_room6_mix118.csv, (600, 56)
# 564: fold1_room6_mix123.csv, (600, 56)
# 565: fold1_room3_mix043.csv, (600, 56)
# 566: fold1_room2_mix098.csv, (600, 56)
# 567: fold1_room2_mix069.csv, (600, 56)
# 568: fold1_room2_mix123.csv, (600, 56)
# 569: fold1_room5_mix068.csv, (600, 56)
# 570: fold1_room5_mix074.csv, (600, 56)
# 571: fold1_room4_mix003.csv, (600, 56)
# 572: fold1_room3_mix123.csv, (600, 56)
# 573: fold1_room5_mix064.csv, (600, 56)
# 574: fold1_room6_mix047.csv, (600, 56)
# 575: fold1_room4_mix052.csv, (600, 56)
# 576: fold1_room3_mix117.csv, (600, 56)
# 577: fold1_room3_mix090.csv, (600, 56)
# 578: fold1_room3_mix036.csv, (600, 56)
# 579: fold1_room5_mix054.csv, (600, 56)
# 580: fold1_room6_mix109.csv, (600, 56)
# 581: fold1_room6_mix071.csv, (600, 56)
# 582: fold1_room2_mix046.csv, (600, 56)
# 583: fold1_room4_mix032.csv, (600, 56)
# 584: fold1_room6_mix055.csv, (600, 56)
# 585: fold1_room1_mix108.csv, (600, 56)
# 586: fold1_room3_mix007.csv, (600, 56)
# 587: fold1_room4_mix096.csv, (600, 56)
# 588: fold1_room3_mix133.csv, (600, 56)
# 589: fold1_room2_mix038.csv, (600, 56)
# 590: fold1_room3_mix085.csv, (600, 56)
# 591: fold1_room6_mix012.csv, (600, 56)
# 592: fold1_room6_mix116.csv, (600, 56)
# 593: fold1_room3_mix082.csv, (600, 56)
# 594: fold1_room5_mix024.csv, (600, 56)
# 595: fold1_room4_mix033.csv, (600, 56)
# 596: fold1_room2_mix082.csv, (600, 56)
# 597: fold1_room6_mix009.csv, (600, 56)
# 598: fold1_room3_mix115.csv, (600, 56)
# 599: fold1_room5_mix014.csv, (600, 56)
# 600: fold1_room2_mix114.csv, (600, 56)
# 601: fold1_room2_mix093.csv, (600, 56)
# 602: fold1_room6_mix101.csv, (600, 56)
# 603: fold1_room2_mix097.csv, (600, 56)
# 604: fold1_room1_mix123.csv, (600, 56)
# 605: fold1_room5_mix117.csv, (600, 56)
# 606: fold1_room5_mix089.csv, (600, 56)
# 607: fold1_room4_mix124.csv, (600, 56)
# 608: fold1_room5_mix030.csv, (600, 56)
# 609: fold1_room6_mix114.csv, (600, 56)
# 610: fold1_room5_mix020.csv, (600, 56)
# 611: fold1_room3_mix124.csv, (600, 56)
# 612: fold1_room1_mix096.csv, (600, 56)
# 613: fold1_room2_mix091.csv, (600, 56)
# 614: fold1_room5_mix086.csv, (600, 56)
# 615: fold1_room2_mix076.csv, (600, 56)
# 616: fold1_room3_mix074.csv, (600, 56)
# 617: fold1_room3_mix048.csv, (600, 56)
# 618: fold1_room1_mix145.csv, (600, 56)
# 619: fold1_room6_mix060.csv, (600, 56)
# 620: fold1_room1_mix116.csv, (600, 56)
# 621: fold1_room2_mix140.csv, (600, 56)
# 622: fold1_room5_mix060.csv, (600, 56)
# 623: fold1_room5_mix013.csv, (600, 56)
# 624: fold1_room2_mix062.csv, (600, 56)
# 625: fold1_room6_mix149.csv, (600, 56)
# 626: fold1_room4_mix141.csv, (600, 56)
# 627: fold1_room3_mix016.csv, (600, 56)
# 628: fold1_room6_mix025.csv, (600, 56)
# 629: fold1_room5_mix133.csv, (600, 56)
# 630: fold1_room2_mix054.csv, (600, 56)
# 631: fold1_room2_mix127.csv, (600, 56)
# 632: fold1_room2_mix074.csv, (600, 56)
# 633: fold1_room6_mix108.csv, (600, 56)
# 634: fold1_room3_mix084.csv, (600, 56)
# 635: fold1_room2_mix026.csv, (600, 56)
# 636: fold1_room6_mix064.csv, (600, 56)
# 637: fold1_room4_mix133.csv, (600, 56)
# 638: fold1_room6_mix045.csv, (600, 56)
# 639: fold1_room6_mix147.csv, (600, 56)
# 640: fold1_room6_mix145.csv, (600, 56)
# 641: fold1_room6_mix092.csv, (600, 56)
# 642: fold1_room5_mix081.csv, (600, 56)
# 643: fold1_room1_mix100.csv, (600, 56)
# 644: fold1_room2_mix139.csv, (600, 56)
# 645: fold1_room6_mix017.csv, (600, 56)
# 646: fold1_room3_mix003.csv, (600, 56)
# 647: fold1_room4_mix132.csv, (600, 56)
# 648: fold1_room2_mix053.csv, (600, 56)
# 649: fold1_room2_mix129.csv, (600, 56)
# 650: fold1_room5_mix026.csv, (600, 56)
# 651: fold1_room5_mix130.csv, (600, 56)
# 652: fold1_room4_mix130.csv, (600, 56)
# 653: fold1_room3_mix039.csv, (600, 56)
# 654: fold1_room2_mix050.csv, (600, 56)
# 655: fold1_room3_mix101.csv, (600, 56)
# 656: fold1_room5_mix129.csv, (600, 56)
# 657: fold1_room3_mix050.csv, (600, 56)
# 658: fold1_room1_mix001.csv, (600, 56)
# 659: fold1_room1_mix063.csv, (600, 56)
# 660: fold1_room3_mix081.csv, (600, 56)
# 661: fold1_room3_mix034.csv, (600, 56)
# 662: fold1_room2_mix131.csv, (600, 56)
# 663: fold1_room4_mix111.csv, (600, 56)
# 664: fold1_room6_mix015.csv, (600, 56)
# 665: fold1_room2_mix072.csv, (600, 56)
# 666: fold1_room2_mix019.csv, (600, 56)
# 667: fold1_room4_mix038.csv, (600, 56)
# 668: fold1_room2_mix122.csv, (600, 56)
# 669: fold1_room6_mix031.csv, (600, 56)
# 670: fold1_room6_mix059.csv, (600, 56)
# 671: fold1_room4_mix018.csv, (600, 56)
# 672: fold1_room4_mix118.csv, (600, 56)
# 673: fold1_room2_mix016.csv, (600, 56)
# 674: fold1_room2_mix001.csv, (600, 56)
# 675: fold1_room2_mix011.csv, (600, 56)
# 676: fold1_room5_mix101.csv, (600, 56)
# 677: fold1_room3_mix010.csv, (600, 56)
# 678: fold1_room2_mix135.csv, (600, 56)
# 679: fold1_room5_mix111.csv, (600, 56)
# 680: fold1_room5_mix113.csv, (600, 56)
# 681: fold1_room2_mix134.csv, (600, 56)
# 682: fold1_room6_mix095.csv, (600, 56)
# 683: fold1_room6_mix119.csv, (600, 56)
# 684: fold1_room4_mix007.csv, (600, 56)
# 685: fold1_room6_mix137.csv, (600, 56)
# 686: fold1_room1_mix031.csv, (600, 56)
# 687: fold1_room5_mix126.csv, (600, 56)
# 688: fold1_room5_mix147.csv, (600, 56)
# 689: fold1_room2_mix031.csv, (600, 56)
# 690: fold1_room3_mix056.csv, (600, 56)
# 691: fold1_room5_mix079.csv, (600, 56)
# 692: fold1_room4_mix031.csv, (600, 56)
# 693: fold1_room1_mix029.csv, (600, 56)
# 694: fold1_room1_mix091.csv, (600, 56)
# 695: fold1_room1_mix002.csv, (600, 56)
# 696: fold1_room4_mix115.csv, (600, 56)
# 697: fold1_room6_mix035.csv, (600, 56)
# 698: fold1_room3_mix147.csv, (600, 56)
# 699: fold1_room2_mix147.csv, (600, 56)
# 700: fold1_room4_mix069.csv, (600, 56)
# 701: fold1_room2_mix099.csv, (600, 56)
# 702: fold1_room3_mix121.csv, (600, 56)
# 703: fold1_room1_mix148.csv, (600, 56)
# 704: fold1_room1_mix016.csv, (600, 56)
# 705: fold1_room2_mix024.csv, (600, 56)
# 706: fold1_room3_mix097.csv, (600, 56)
# 707: fold1_room5_mix046.csv, (600, 56)
# 708: fold1_room4_mix082.csv, (600, 56)
# 709: fold1_room1_mix134.csv, (600, 56)
# 710: fold1_room6_mix003.csv, (600, 56)
# 711: fold1_room2_mix148.csv, (600, 56)
# 712: fold1_room6_mix006.csv, (600, 56)
# 713: fold1_room1_mix022.csv, (600, 56)
# 714: fold1_room2_mix059.csv, (600, 56)
# 715: fold1_room5_mix045.csv, (600, 56)
# 716: fold1_room6_mix033.csv, (600, 56)
# 717: fold1_room2_mix070.csv, (600, 56)
# 718: fold1_room1_mix037.csv, (600, 56)
# 719: fold1_room1_mix131.csv, (600, 56)
# 720: fold1_room4_mix006.csv, (600, 56)
# 721: fold1_room6_mix044.csv, (600, 56)
# 722: fold1_room6_mix053.csv, (600, 56)
# 723: fold1_room6_mix142.csv, (600, 56)
# 724: fold1_room3_mix148.csv, (600, 56)
# 725: fold1_room3_mix099.csv, (600, 56)
# 726: fold1_room4_mix097.csv, (600, 56)
# 727: fold1_room3_mix120.csv, (600, 56)
# 728: fold1_room6_mix122.csv, (600, 56)
# 729: fold1_room4_mix070.csv, (600, 56)
# 730: fold1_room5_mix056.csv, (600, 56)
# 731: fold1_room3_mix105.csv, (600, 56)
# 732: fold1_room6_mix008.csv, (600, 56)
# 733: fold1_room6_mix038.csv, (600, 56)
# 734: fold1_room6_mix019.csv, (600, 56)
# 735: fold1_room5_mix069.csv, (600, 56)
# 736: fold1_room6_mix099.csv, (600, 56)
# 737: fold1_room3_mix113.csv, (600, 56)
# 738: fold1_room1_mix114.csv, (600, 56)
# 739: fold1_room4_mix109.csv, (600, 56)
# 740: fold1_room1_mix064.csv, (600, 56)
# 741: fold1_room1_mix104.csv, (600, 56)
# 742: fold1_room4_mix099.csv, (600, 56)
# 743: fold1_room6_mix088.csv, (600, 56)
# 744: fold1_room1_mix061.csv, (600, 56)
# 745: fold1_room1_mix090.csv, (600, 56)
# 746: fold1_room1_mix075.csv, (600, 56)
# 747: fold1_room1_mix040.csv, (600, 56)
# 748: fold1_room2_mix130.csv, (600, 56)
# 749: fold1_room4_mix101.csv, (600, 56)
# 750: fold1_room6_mix073.csv, (600, 56)
# 751: fold1_room6_mix121.csv, (600, 56)
# 752: fold1_room2_mix106.csv, (600, 56)
# 753: fold1_room2_mix042.csv, (600, 56)
# 754: fold1_room4_mix126.csv, (600, 56)
# 755: fold1_room2_mix032.csv, (600, 56)
# 756: fold1_room1_mix017.csv, (600, 56)
# 757: fold1_room6_mix061.csv, (600, 56)
# 758: fold1_room6_mix080.csv, (600, 56)
# 759: fold1_room3_mix107.csv, (600, 56)
# 760: fold1_room2_mix051.csv, (600, 56)
# 761: fold1_room2_mix067.csv, (600, 56)
# 762: fold1_room5_mix040.csv, (600, 56)
# 763: fold1_room4_mix095.csv, (600, 56)
# 764: fold1_room1_mix122.csv, (600, 56)
# 765: fold1_room4_mix016.csv, (600, 56)
# 766: fold1_room3_mix109.csv, (600, 56)
# 767: fold1_room2_mix121.csv, (600, 56)
# 768: fold1_room5_mix025.csv, (600, 56)
# 769: fold1_room6_mix052.csv, (600, 56)
# 770: fold1_room5_mix145.csv, (600, 56)
# 771: fold1_room4_mix149.csv, (600, 56)
# 772: fold1_room1_mix012.csv, (600, 56)
# 773: fold1_room5_mix055.csv, (600, 56)
# 774: fold1_room5_mix099.csv, (600, 56)
# 775: fold1_room1_mix052.csv, (600, 56)
# 776: fold1_room2_mix145.csv, (600, 56)
# 777: fold1_room2_mix057.csv, (600, 56)
# 778: fold1_room2_mix002.csv, (600, 56)
# 779: fold1_room2_mix133.csv, (600, 56)
# 780: fold1_room6_mix117.csv, (600, 56)
# 781: fold1_room2_mix036.csv, (600, 56)
# 782: fold1_room6_mix138.csv, (600, 56)
# 783: fold1_room4_mix056.csv, (600, 56)
# 784: fold1_room6_mix150.csv, (600, 56)
# 785: fold1_room6_mix014.csv, (600, 56)
# 786: fold1_room4_mix001.csv, (600, 56)
# 787: fold1_room5_mix019.csv, (600, 56)
# 788: fold1_room5_mix096.csv, (600, 56)
# 789: fold1_room3_mix023.csv, (600, 56)
# 790: fold1_room3_mix083.csv, (600, 56)
# 791: fold1_room3_mix125.csv, (600, 56)
# 792: fold1_room6_mix054.csv, (600, 56)
# 793: fold1_room1_mix120.csv, (600, 56)
# 794: fold1_room1_mix137.csv, (600, 56)
# 795: fold1_room2_mix063.csv, (600, 56)
# 796: fold1_room3_mix008.csv, (600, 56)
# 797: fold1_room5_mix087.csv, (600, 56)
# 798: fold1_room6_mix089.csv, (600, 56)
# 799: fold1_room4_mix128.csv, (600, 56)
# 800: fold1_room3_mix065.csv, (600, 56)
# 801: fold1_room6_mix104.csv, (600, 56)
# 802: fold1_room1_mix054.csv, (600, 56)
# 803: fold1_room4_mix037.csv, (600, 56)
# 804: fold1_room3_mix011.csv, (600, 56)
# 805: fold1_room1_mix150.csv, (600, 56)
# 806: fold1_room3_mix079.csv, (600, 56)
# 807: fold1_room2_mix073.csv, (600, 56)
# 808: fold1_room5_mix007.csv, (600, 56)
# 809: fold1_room2_mix015.csv, (600, 56)
# 810: fold1_room4_mix027.csv, (600, 56)
# 811: fold1_room3_mix140.csv, (600, 56)
# 812: fold1_room4_mix085.csv, (600, 56)
# 813: fold1_room6_mix130.csv, (600, 56)
# 814: fold1_room1_mix083.csv, (600, 56)
# 815: fold1_room3_mix102.csv, (600, 56)
# 816: fold1_room2_mix058.csv, (600, 56)
# 817: fold1_room1_mix126.csv, (600, 56)
# 818: fold1_room1_mix130.csv, (600, 56)
# 819: fold1_room1_mix036.csv, (600, 56)
# 820: fold1_room2_mix037.csv, (600, 56)
# 821: fold1_room3_mix026.csv, (600, 56)
# 822: fold1_room5_mix021.csv, (600, 56)
# 823: fold1_room1_mix121.csv, (600, 56)
# 824: fold1_room6_mix057.csv, (600, 56)
# 825: fold1_room3_mix009.csv, (600, 56)
# 826: fold1_room6_mix129.csv, (600, 56)
# 827: fold1_room3_mix064.csv, (600, 56)
# 828: fold1_room2_mix092.csv, (600, 56)
# 829: fold1_room6_mix124.csv, (600, 56)
# 830: fold1_room3_mix118.csv, (600, 56)
# 831: fold1_room4_mix137.csv, (600, 56)
# 832: fold1_room5_mix148.csv, (600, 56)
# 833: fold1_room3_mix022.csv, (600, 56)
# 834: fold1_room5_mix122.csv, (600, 56)
# 835: fold1_room5_mix039.csv, (600, 56)
# 836: fold1_room5_mix106.csv, (600, 56)
# 837: fold1_room4_mix122.csv, (600, 56)
# 838: fold1_room5_mix066.csv, (600, 56)
# 839: fold1_room3_mix059.csv, (600, 56)
# 840: fold1_room3_mix126.csv, (600, 56)
# 841: fold1_room6_mix079.csv, (600, 56)
# 842: fold1_room1_mix128.csv, (600, 56)
# 843: fold1_room1_mix021.csv, (600, 56)
# 844: fold1_room2_mix013.csv, (600, 56)
# 845: fold1_room4_mix067.csv, (600, 56)
# 846: fold1_room3_mix091.csv, (600, 56)
# 847: fold1_room4_mix060.csv, (600, 56)
# 848: fold1_room1_mix056.csv, (600, 56)
# 849: fold1_room3_mix068.csv, (600, 56)
# 850: fold1_room2_mix005.csv, (600, 56)
# 851: fold1_room2_mix040.csv, (600, 56)
# 852: fold1_room4_mix046.csv, (600, 56)
# 853: fold1_room4_mix017.csv, (600, 56)
# 854: fold1_room4_mix026.csv, (600, 56)
# 855: fold1_room3_mix095.csv, (600, 56)
# 856: fold1_room2_mix049.csv, (600, 56)
# 857: fold1_room3_mix054.csv, (600, 56)
# 858: fold1_room4_mix104.csv, (600, 56)
# 859: fold1_room4_mix127.csv, (600, 56)
# 860: fold1_room5_mix016.csv, (600, 56)
# 861: fold1_room6_mix075.csv, (600, 56)
# 862: fold1_room2_mix079.csv, (600, 56)
# 863: fold1_room6_mix056.csv, (600, 56)
# 864: fold1_room4_mix143.csv, (600, 56)
# 865: fold1_room5_mix119.csv, (600, 56)
# 866: fold1_room2_mix143.csv, (600, 56)
# 867: fold1_room1_mix044.csv, (600, 56)
# 868: fold1_room4_mix045.csv, (600, 56)
# 869: fold1_room2_mix035.csv, (600, 56)
# 870: fold1_room4_mix042.csv, (600, 56)
# 871: fold1_room6_mix048.csv, (600, 56)
# 872: fold1_room1_mix024.csv, (600, 56)
# 873: fold1_room3_mix136.csv, (600, 56)
# 874: fold1_room2_mix044.csv, (600, 56)
# 875: fold1_room4_mix135.csv, (600, 56)
# 876: fold1_room2_mix146.csv, (600, 56)
# 877: fold1_room6_mix098.csv, (600, 56)
# 878: fold1_room1_mix143.csv, (600, 56)
# 879: fold1_room5_mix114.csv, (600, 56)
# 880: fold1_room1_mix094.csv, (600, 56)
# 881: fold1_room1_mix124.csv, (600, 56)
# 882: fold1_room3_mix066.csv, (600, 56)
# 883: fold1_room5_mix058.csv, (600, 56)
# 884: fold1_room1_mix066.csv, (600, 56)
# 885: fold1_room3_mix020.csv, (600, 56)
# 886: fold1_room3_mix038.csv, (600, 56)
# 887: fold1_room2_mix048.csv, (600, 56)
# 888: fold1_room3_mix106.csv, (600, 56)
# 889: fold1_room5_mix065.csv, (600, 56)
# 890: fold1_room4_mix044.csv, (600, 56)
# 891: fold1_room1_mix139.csv, (600, 56)
# 892: fold1_room3_mix108.csv, (600, 56)
# 893: fold1_room3_mix005.csv, (600, 56)
# 894: fold1_room3_mix028.csv, (600, 56)
# 895: fold1_room6_mix096.csv, (600, 56)
# 896: fold1_room3_mix100.csv, (600, 56)
# 897: fold1_room5_mix076.csv, (600, 56)
# 898: fold1_room1_mix092.csv, (600, 56)
# 899: fold1_room5_mix029.csv, (600, 56)

# %%
/scratch/ci411/DCASE_GEN/mixtures/nigens_tau_real/target_noiseless/mic_dev
/scratch/ci411/STARSS2022/mic_dev/dev-train-tau
